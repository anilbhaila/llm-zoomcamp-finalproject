# %%
import sys
import os

# 1. Direct Python to the root project folder
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.ingest import load_faq_data
documents = load_faq_data()

# %%
from sqlitesearch import TextSearchIndex

index = TextSearchIndex(
    text_fields = ['question', 'answer'],
    db_path='../data/faq.db'
)

# %%
import time

for doc in documents:
    index.add(doc)
    print(f'Added: {doc["question"][:60]}...')
    time.sleep(0.5)

index.close()
print('Done. Index saved to ../data/faq.db')
# Out:
# Added: How can I create an account?...
# Added: What payment methods do you accept?...
# Added: How can I track my order?...
# Added: What is your return policy?...
# Added: Can I cancel my order?...
# Added: How long does shipping take?...
# Added: Do you offer international shipping?...
# Added: What should I do if my package is lost or damaged?...
# Added: Can I change my shipping address after placing an order?...
# Added: How can I contact customer support?...
# Added: Do you offer gift wrapping services?...
# Added: What is your price matching policy?...
# Added: Can I order by phone?...
# Added: Are my personal and payment details secure?...
# Added: What is your price adjustment policy?...
# Added: Do you have a loyalty program?...
# Added: Can I order without creating an account?...
# Added: Do you offer bulk or wholesale discounts?...
# Added: Can I change or cancel an item in my order?...
# Added: How can I leave a product review?...
# Added: Can I use multiple promo codes on a single order?...
# Added: What should I do if I receive the wrong item?...
# Added: Do you offer expedited shipping?...
# Added: Can I order a product that is out of stock?...
# Added: What is your email newsletter about?...
# Added: Can I return a product if I changed my mind?...
# Added: Do you offer live chat support?...
# Added: Can I order a product as a gift?...
# Added: What should I do if my discount code is not working?...
# Added: Can I return a product if it was a final sale item?...
# Added: Do you offer installation services for your products?...
# Added: Can I order a product that is discontinued?...
# Added: Can I return a product without a receipt?...
# Added: Can I order a product for delivery to a different country?...
# Added: Can I add a gift message to my order?...
# Added: Can I request a product demonstration before making a purcha...
# Added: Can I order a product that is listed as 'coming soon'?...
# Added: Can I request an invoice for my order?...
# Added: Can I order a product that is labeled as 'limited edition'?...
# Added: Can I return a product if I no longer have the original pack...
# Added: Can I request a product that is currently out of stock to be...
# Added: Can I order a product that is listed as 'pre-order' with oth...
# Added: Can I return a product if it was damaged during shipping?...
# Added: Can I request a product that is out of stock to be restocked...
# Added: Can I order a product if it is listed as 'backordered'?...
# Added: Can I return a product if it was purchased during a sale or ...
# Added: Can I request a product repair or replacement if it is damag...
# Added: Can I order a product if it is listed as 'out of stock' but ...
# Added: Can I return a product if it was purchased as a gift?...
# Added: Can I request a product if it is listed as 'discontinued'?...
# Added: Can I order a product if it is listed as 'sold out'?...
# Added: Can I return a product if it was purchased with a gift card?...
# Added: Can I request a product if it is not currently available in ...
# Added: Can I order a product if it is listed as 'coming soon' but a...
# Added: Can I return a product if it was purchased with a discount c...
# Added: Can I request a custom order or personalized product?...
# Added: Can I order a product if it is listed as 'temporarily unavai...
# Added: Can I return a product if it was damaged due to improper use...
# Added: Can I request a product if it is listed as 'coming soon' but...
# Added: Can I order a product if it is listed as 'on hold'?...
# Added: Can I return a product if I no longer have the original rece...
# Added: Can I request a product that is listed as 'limited edition' ...
# Added: Can I order a product if it is listed as 'discontinued' but ...
# Added: Can I return a product if it was a clearance or final sale i...
# Added: Can I request a product if it is not listed on your website?...
# Added: Can I order a product if it is listed as 'out of stock' but ...
# Added: Can I return a product if it was purchased as part of a bund...
# Added: Can I request a product that is listed as 'out of stock' to ...
# Added: Can I order a product if it is listed as 'coming soon' and a...
# Added: Can I return a product if it was damaged due to mishandling ...
# Added: Can I request a product that is listed as 'out of stock' to ...
# Added: Can I order a product if it is listed as 'pre-order' but ava...
# Added: Can I return a product if it was purchased with store credit...
# Added: Can I request a product that is currently out of stock to be...
# Added: Can I order a product if it is listed as 'sold out' but avai...
# Added: Can I return a product if it was purchased with a promotiona...
# Added: Can I request a product if it is not currently available in ...
# Added: Can I order a product if it is listed as 'coming soon' and n...
# Added: Can I return a product if it was purchased during a promotio...
# Done. Index saved to faq.db
